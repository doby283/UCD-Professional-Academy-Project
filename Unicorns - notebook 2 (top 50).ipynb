# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv (r'Desktop/unicorn50.csv')

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#                    Company Valuation ($B) Date Joined         Country  \
# 0                Bytedance           $140  04/07/2017           China
# 1                   SpaceX         $100.3  12/01/2012   United States
# 2                   Stripe            $95   1/23/2014   United States
# 3                   Klarna          $45.6  12/12/2011          Sweden
# 4               Epic Games            $42  10/26/2018   United States
# 5                    Canva            $40  01/08/2018       Australia
# 6             Checkout.com            $40  05/02/2019  United Kingdom
# 7                Instacart            $39  12/30/2014   United States
# 8               Databricks            $38  02/05/2019   United States
# 9                  Revolut            $33   4/26/2018  United Kingdom
# 10                     FTX            $32   7/20/2021         Bahamas
# 11                Fanatics            $27  06/06/2012   United States
# ...

# %%
sns.scatterplot(data=df, x="Country", y="Valuation ($B)", hue="Valuation ($B)", size= "Valuation ($B)").set(
    title="Company valuation vs Country of origin")
sns.set(rc={'figure.figsize':(25,25)})

# %%
sns.scatterplot(data=data, x="Country", y="Valuation ($B)", size="Valuation ($B)", legend=False, sizes=(20, 2000)).set(
    title="Company valuation vs Country of origin")
# Out:
# [Text(0.5, 1.0, 'Company valuation vs Country of origin')]
